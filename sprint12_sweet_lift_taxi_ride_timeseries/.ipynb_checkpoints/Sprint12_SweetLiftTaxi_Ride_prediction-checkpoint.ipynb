# %% [markdown]
# # Project description
#
# Sweet Lift Taxi company has collected historical data on taxi orders at airports. To attract more drivers during peak hours, we need to predict the amount of taxi orders for the next hour. Build a model for such a prediction.
#
# The RMSE metric on the test set should not be more than 48.
#
# ## Project instructions
#
# 1. Download the data and resample it by one hour.
# 2. Analyze the data.
# 3. Train different models with different hyperparameters. The test sample should be 10% of the initial dataset.
# 4. Test the data using the test sample and provide a conclusion.
#
# ## Data description
#
# The data is stored in file `taxi.csv`. The number of orders is in the '*num_orders*' column.

# %%
import pandas as pd
import numpy as np
import os, sys
import matplotlib.pyplot as plt
import seaborn as sns
import time

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, make_scorer
from sklearn.model_selection import train_test_split, TimeSeriesSplit, GridSearchCV

from catboost import CatBoostRegressor
from statsmodels.tsa.seasonal import seasonal_decompose

import warnings
warnings.filterwarnings('ignore')

# %%
# read the data
df = pd.read_csv('/datasets/taxi.csv', parse_dates=['datetime'])

# %%
# shapes
df.shape
# Out:
# (26496, 2)

# %%
# top 5
df.head()
# Out:
#              datetime  num_orders
# 0 2018-03-01 00:00:00           9
# 1 2018-03-01 00:10:00          14
# 2 2018-03-01 00:20:00          28
# 3 2018-03-01 00:30:00          20
# 4 2018-03-01 00:40:00          32

# %%
# check for missing
df.isnull().mean()
# Out:
# datetime      0.0
# num_orders    0.0
# dtype: float64

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# 5 point summary
df.describe()
# Out:
#          num_orders
# count  26496.000000
# mean      14.070463
# std        9.211330
# min        0.000000
# 25%        8.000000
# 50%       13.000000
# 75%       19.000000
# max      119.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26496 entries, 0 to 26495
# Data columns (total 2 columns):
# datetime      26496 non-null datetime64[ns]
# num_orders    26496 non-null int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 414.1 KB

# %%
# duration of the dataset
df['datetime'].min(), df['datetime'].max()
# Out:
# (Timestamp('2018-03-01 00:00:00'), Timestamp('2018-08-31 23:50:00'))

# %%
# check for gaps
(df['datetime'] - df['datetime'].shift()).plot()
plt.show()

# %% [markdown]
# **Conclusion**
#
# 1) There are 26496 orders captured at 10 minute intervals starting from 2018-03-01 to 2018-08-31.
#
# 2) There are no duplicates or misisng values
#
# 3) The datasets is time ordered and there are no gaps.
#
# 4) The mean number of orders is 14, and the ordes range from 0 - 119.

# %% [markdown]
# ## Preparation and Analysis

# %% [markdown]
# #### Create new features
#
# * Add date features (month, day, dayofweek, hour)
# * Add rolling mean
# * Add rolling median
# * Add rolling std

# %%
# predictions are required for the next hour
df_hourly = df.copy(deep=True)
df_hourly.set_index('datetime', inplace=True)
df_hourly = df_hourly.resample('1H').sum()

# %%
def create_ts_features(df, dt_field, target, max_lag=1, rolling_window=1):
    """
    Create several Timseries features
    """
    df['month'] = df.index.month
    df['day'] = df.index.day
    df['dayofweek'] = df.index.dayofweek
    df['hour'] = df.index.hour
    
    for lag in range(1, max_lag+1):
        df['lag_{}'.format(str(lag))] = df[target].shift(lag)
    
    df['rolling_mean'] = df[target].shift().rolling(rolling_window).mean()
    df['rolling_median'] = df[target].shift().rolling(rolling_window).median()
    df['rolling_std'] = df[target].shift().rolling(rolling_window).std()

# %%
create_ts_features(df_hourly, 'datetime', 'num_orders', max_lag=7, rolling_window=7)

# %%
df_hourly.head(8)
# Out:
#                      num_orders  month  day  dayofweek  hour  lag_1  lag_2  \
# datetime
# 2018-03-01 00:00:00         124      3    1          3     0    NaN    NaN
# 2018-03-01 01:00:00          85      3    1          3     1  124.0    NaN
# 2018-03-01 02:00:00          71      3    1          3     2   85.0  124.0
# 2018-03-01 03:00:00          66      3    1          3     3   71.0   85.0
# 2018-03-01 04:00:00          43      3    1          3     4   66.0   71.0
# 2018-03-01 05:00:00           6      3    1          3     5   43.0   66.0
# 2018-03-01 06:00:00          12      3    1          3     6    6.0   43.0
# 2018-03-01 07:00:00          15      3    1          3     7   12.0    6.0
#
#                      lag_3  lag_4  lag_5  lag_6  lag_7  rolling_mean  \
# datetime
# 2018-03-01 00:00:00    NaN    NaN    NaN    NaN    NaN           NaN
# 2018-03-01 01:00:00    NaN    NaN    NaN    NaN    NaN           NaN
# 2018-03-01 02:00:00    NaN    NaN    NaN    NaN    NaN           NaN
# 2018-03-01 03:00:00  124.0    NaN    NaN    NaN    NaN           NaN
# 2018-03-01 04:00:00   85.0  124.0    NaN    NaN    NaN           NaN
# 2018-03-01 05:00:00   71.0   85.0  124.0    NaN    NaN           NaN
# 2018-03-01 06:00:00   66.0   71.0   85.0  124.0    NaN           NaN
# 2018-03-01 07:00:00   43.0   66.0   71.0   85.0  124.0     58.142857
#
#                      rolling_median  rolling_std
# datetime
# 2018-03-01 00:00:00             NaN          NaN
# 2018-03-01 01:00:00             NaN          NaN
# 2018-03-01 02:00:00             NaN          NaN
# 2018-03-01 03:00:00             NaN          NaN
# 2018-03-01 04:00:00             NaN          NaN
# 2018-03-01 05:00:00             NaN          NaN
# 2018-03-01 06:00:00             NaN          NaN
# 2018-03-01 07:00:00            66.0    41.558908

# %% [markdown]
# #### Change the dtypes

# %%
df_hourly.describe()
# Out:
#         num_orders        month          day    dayofweek        hour  \
# count  4416.000000  4416.000000  4416.000000  4416.000000  4416.00000
# mean     84.422781     5.505435    15.836957     3.005435    11.50000
# std      45.023853     1.713306     8.855229     1.990684     6.92297
# min       0.000000     3.000000     1.000000     0.000000     0.00000
# 25%      54.000000     4.000000     8.000000     1.000000     5.75000
# 50%      78.000000     5.500000    16.000000     3.000000    11.50000
# 75%     107.000000     7.000000    23.250000     5.000000    17.25000
# max     462.000000     8.000000    31.000000     6.000000    23.00000
#
#              lag_1        lag_2        lag_3        lag_4        lag_5  \
# count  4415.000000  4414.000000  4413.000000  4412.000000  4411.000000
# mean     84.395470    84.364069    84.347156    84.331369    84.319655
# std      44.992356    44.949043    44.940088    44.932942    44.931299
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      54.000000    54.000000    54.000000    54.000000    54.000000
# 50%      78.000000    78.000000    78.000000    78.000000    78.000000
# 75%     107.000000   107.000000   107.000000   107.000000   107.000000
# max     462.000000   462.000000   462.000000   462.000000   462.000000
#
#              lag_6        lag_7  rolling_mean  rolling_median  rolling_std
# count  4410.000000  4409.000000   4409.000000     4409.000000  4409.000000
# mean     84.291837    84.261737     84.331108       82.863688    30.913356
# std      44.898387    44.858959     31.807426       32.062825    14.822064
# min       0.000000     0.000000     21.000000       17.000000     5.814596
# 25%      54.000000    54.000000     62.285714       61.000000    21.037382
# 50%      78.000000    78.000000     79.428571       78.000000    27.944673
# 75%     107.000000   107.000000    101.571429      101.000000    37.235416
# max     462.000000   462.000000    254.142857      238.000000   151.400918

# %%
# before the change
df_hourly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4416 entries, 2018-03-01 00:00:00 to 2018-08-31 23:00:00
# Freq: H
# Data columns (total 15 columns):
# num_orders        4416 non-null int64
# month             4416 non-null int64
# day               4416 non-null int64
# dayofweek         4416 non-null int64
# hour              4416 non-null int64
# lag_1             4415 non-null float64
# lag_2             4414 non-null float64
# lag_3             4413 non-null float64
# lag_4             4412 non-null float64
# lag_5             4411 non-null float64
# lag_6             4410 non-null float64
# lag_7             4409 non-null float64
# rolling_mean      4409 non-null float64
# rolling_median    4409 non-null float64
# rolling_std       4409 non-null float64
# dtypes: float64(10), int64(5)
# memory usage: 552.0 KB

# %%
cols_to_change = [
                 'lag_1', 'lag_2', 'lag_3', 'lag_4', 'lag_5', 'lag_6', 'lag_7',
                 'rolling_median'
]
df_hourly[cols_to_change] = df_hourly[cols_to_change].astype('Int16')

# %%
# after the change
df_hourly.describe()
# Out:
#         num_orders        month          day    dayofweek        hour  \
# count  4416.000000  4416.000000  4416.000000  4416.000000  4416.00000
# mean     84.422781     5.505435    15.836957     3.005435    11.50000
# std      45.023853     1.713306     8.855229     1.990684     6.92297
# min       0.000000     3.000000     1.000000     0.000000     0.00000
# 25%      54.000000     4.000000     8.000000     1.000000     5.75000
# 50%      78.000000     5.500000    16.000000     3.000000    11.50000
# 75%     107.000000     7.000000    23.250000     5.000000    17.25000
# max     462.000000     8.000000    31.000000     6.000000    23.00000
#
#              lag_1        lag_2        lag_3        lag_4        lag_5  \
# count  4415.000000  4414.000000  4413.000000  4412.000000  4411.000000
# mean     84.395470    84.364069    84.347156    84.331369    84.319655
# std      44.992356    44.949043    44.940088    44.932942    44.931299
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      54.000000    54.000000    54.000000    54.000000    54.000000
# 50%      78.000000    78.000000    78.000000    78.000000    78.000000
# 75%     107.000000   107.000000   107.000000   107.000000   107.000000
# max     462.000000   462.000000   462.000000   462.000000   462.000000
#
#              lag_6        lag_7  rolling_mean  rolling_median  rolling_std
# count  4410.000000  4409.000000   4409.000000     4409.000000  4409.000000
# mean     84.291837    84.261737     84.331108       82.863688    30.913356
# std      44.898387    44.858959     31.807426       32.062825    14.822064
# min       0.000000     0.000000     21.000000       17.000000     5.814596
# 25%      54.000000    54.000000     62.285714       61.000000    21.037382
# 50%      78.000000    78.000000     79.428571       78.000000    27.944673
# 75%     107.000000   107.000000    101.571429      101.000000    37.235416
# max     462.000000   462.000000    254.142857      238.000000   151.400918

# %%
# after the change
df_hourly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4416 entries, 2018-03-01 00:00:00 to 2018-08-31 23:00:00
# Freq: H
# Data columns (total 15 columns):
# num_orders        4416 non-null int64
# month             4416 non-null int64
# day               4416 non-null int64
# dayofweek         4416 non-null int64
# hour              4416 non-null int64
# lag_1             4415 non-null Int16
# lag_2             4414 non-null Int16
# lag_3             4413 non-null Int16
# lag_4             4412 non-null Int16
# lag_5             4411 non-null Int16
# lag_6             4410 non-null Int16
# lag_7             4409 non-null Int16
# rolling_mean      4409 non-null float64
# rolling_median    4409 non-null Int16
# rolling_std       4409 non-null float64
# dtypes: Int16(8), float64(2), int64(5)
# memory usage: 379.5 KB

# %% [markdown]
# #### Plot time-series orders using different intervals

# %%
def plot_orders(dfs, field, r=1, c=1, figsize=(12, 10), is_mean_window=False,
                window=1, titles=[], sup_title=None):
    """
    Plot mean orders based on different time intervals
    """
    fig, axes = plt.subplots(r, c, figsize=figsize)
    if not is_mean_window:
        for idx, (df, title, ax) in enumerate(zip(dfs, titles, axes.flatten())):
            sns.lineplot(df.index, df, ax=ax)
            axes[idx].set_title(title)
    else:
        for idx, (df, title, ax) in enumerate(zip(dfs, titles, axes.flatten())):
            sns.lineplot(df.index, df, ax=ax, label='hourly trend')
            sns.lineplot(df.index, df.shift().rolling(window).mean(), ax=ax, label='mean')
            sns.lineplot(df.index, df.shift().rolling(window).std(), ax=ax, label='std')
            axes[idx].set_title(title)
    axes.flat[-1].set_visible(False) 
    plt.suptitle(sup_title)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

# %%
# resample the dataframe on an hourly, daily, and monthly basis
hourly_orders = df.set_index('datetime')['num_orders'].resample('1H').mean()
daily_orders = df.set_index('datetime')['num_orders'].resample('1D').mean()
monthly_orders = df.set_index('datetime')['num_orders'].resample('1M').mean()

# %%
resample_df_list = [hourly_orders, daily_orders, monthly_orders]
titles = ['Hourly mean orders',
         'Daily mean orders',
         'Montly mean orders'
         ]
sup_title = 'Trend of orders by various intervals - 2018-03-01 to 2018-08-31'
plot_orders(resample_df_list, 'num_orders', r=4, c=1, titles=titles, sup_title=sup_title)

# %% [markdown]
# 1) The overall trend reveals an upward trend in mean orders between 2018-03-01 and 2018-08-31.

# %%
plt.subplots(figsize=(9, 7))
df['num_orders'].plot(kind='hist', bins=50, title='Distribution of all orders')
plt.show()

# %% [markdown]
# 1) The histogram reveals a right-skewed distribution, which peaks at 9-12 orders.

# %% [markdown]
# #### Heatmap of orders by hour of day and day of week

# %%
pivoted_df = df_hourly.pivot_table(index=['hour'], columns=['dayofweek'], values=['num_orders'], aggfunc='mean')
pivoted_df = pivoted_df.droplevel(0, axis=1)
plt.figure(figsize=(10, 10))
sns.heatmap(pivoted_df, annot=True, cmap="RdYlGn", fmt=".0f")
plt.title('Mean number of orders by day of week and hour of day')
plt.show()

# %% [markdown]
# 1) Between 5AM -7 AM, the mean order of requests drops, and this pattern is observed throughout the week.
#
# 2) 12AM sees a higher than average number of orders compared to any other hour during any given week.
#
# 3) Between 8AM - 8PM, the number of rides is around the mean of 15.

# %%
resample_df_list = [hourly_orders, daily_orders]
titles = [
         'Hourly',
         'Daily'
         ]
window = 7
sup_title = f'{window} hour rolling mean and std on orders - 2018-03-01 to 2018-08-31'
plot_orders(resample_df_list, 'num_orders', r=3, c=1, is_mean_window=True, window=window, 
            titles=titles, sup_title=sup_title)

# %% [markdown]
# 1) The hourly data appears noisy, and the 7 hour mean, and std are noisy. However, in the daily orders, the std appears
# constant, and the mean is relatively smoother.

# %% [markdown]
# #### Decompose the timeseries components

# %%
df_hourly = df_hourly.dropna()

# %%
df_hourly.shape
# Out:
# (4409, 15)

# %%
decomposed = seasonal_decompose(df_hourly[['num_orders', 'rolling_mean', 'rolling_std']])

# %%
decomposed.trend.plot(figsize=(12, 9), title='Trend analysis of hourly orders')
decomposed.seasonal.tail(24*7).plot(figsize=(12, 9), title="Seasonal analysis of last 7 days' hourly orders")
decomposed.resid.plot(figsize=(12, 9), title="Residual plot of hourly orders")
decomposed.seasonal['2018-08-01': '2018-08-02'].plot(figsize=(12, 9), title="Seasonal analysis 1 day' hourly orders")
plt.show()

# %% [markdown]
# 1) The trend plot shows an upward trend.
#
# 2) The seasonal trend for last 7 days shows that there is a daily seasonal pattern in ridership.
#
# 3) The residuals shows that the residual mean is not 0, which indicates that there could be a bias in the predictions. The spikes in August clearly indicate that the company was peaking with respect to ridership frequency.
#
# 4) The seasonal analysis for 1 day shows that ridership frequency increases at midnight, drops to its lowest at 6AM, and then
# rises moderately around 5PM.

# %% [markdown]
# ## Training

# %%
def rmse(y_true, y_pred):
    """
    Make scorer to compute rmse
    """
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
def build_model(model, train_X, train_y, test_X, test_y, 
                hyperparameters={}, 
                scoring=None, cv=5, model_str=None, cat_features=[], verbose=False):
    """
    Build model
    """
    np.random.seed(42)
    best_rmse = 0
    start_time = time.time()
    
    gs = GridSearchCV(model, param_grid=hyperparameters, cv=cv, scoring=scoring)
    gs.fit(train_X, train_y)
    if model_str == 'catboost':
        gs.best_estimator_.fit(train_X, train_y, cat_features=cat_features, verbose=verbose)
    else:
        gs.best_estimator_.fit(train_X, train_y)
    preds = gs.best_estimator_.predict(test_X)
    best_rmse = rmse(test_y, preds)
    end_time = time.time() - start_time
    return gs.best_estimator_, best_rmse, np.round(end_time, 2)

# %%
# split the dataframe
train_X, test_X, train_y, test_y = train_test_split(df_hourly.drop(['num_orders'], axis=1), 
                                              df_hourly['num_orders'], 
                                              test_size=0.2,
                                              random_state=42, shuffle=False)

# %%
train_X.shape, test_X.shape, train_y.shape, test_y.shape
# Out:
# ((3527, 14), (882, 14), (3527,), (882,))

# %%
tscv = TimeSeriesSplit(n_splits=5)

# %%
lr = LinearRegression()
best_lr_model, best_lr_rmse, best_lr_time = build_model(lr, train_X, train_y, 
                                                        test_X, test_y,
                                                        hyperparameters={}, 
                scoring=make_scorer(rmse), cv=tscv)

# %%
rf = RandomForestRegressor(random_state=42)
best_rf_model, best_rf_rmse, best_rf_time = build_model(rf, train_X, train_y, 
                                                        test_X, test_y,
                                                        hyperparameters={'n_estimators': range(100, 600, 100),
                                                                        'max_depth': range(5, 10)
                                                                        }, 
                scoring=make_scorer(rmse), cv=tscv)

# %%
# cat_features = ['month', 'hour', 'day', 'dayofweek']
cat_features = []
cat = CatBoostRegressor(learning_rate=0.1, loss_function='RMSE',
                        random_seed=42)
# 416:	learn: 8.8555389	total: 10.7s	remaining: 2.12s
# 417:	learn: 8.8258874	total: 10.8s	remaining: 2.11s
# 418:	learn: 8.8090350	total: 10.8s	remaining: 2.08s
# 419:	learn: 8.7797907	total: 10.8s	remaining: 2.05s
# 420:	learn: 8.7594594	total: 10.8s	remaining: 2.02s
# 421:	learn: 8.7297596	total: 10.9s	remaining: 2.01s
# 422:	learn: 8.7212208	total: 10.9s	remaining: 1.98s
# 423:	learn: 8.7166404	total: 10.9s	remaining: 1.95s
# 424:	learn: 8.7065115	total: 10.9s	remaining: 1.92s
# 425:	learn: 8.6851554	total: 11s	remaining: 1.9s
# 426:	learn: 8.6724408	total: 11s	remaining: 1.87s
# 427:	learn: 8.6439571	total: 11s	remaining: 1.84s
# 428:	learn: 8.6260155	total: 11s	remaining: 1.81s
# 429:	learn: 8.6112316	total: 11.1s	remaining: 1.8s
# 430:	learn: 8.5826350	total: 11.1s	remaining: 1.77s
# 431:	learn: 8.5720377	total: 11.1s	remaining: 1.74s
# 432:	learn: 8.5592781	total: 11.1s	remaining: 1.71s
# 433:	learn: 8.5441448	total: 11.2s	remaining: 1.7s
# 434:	learn: 8.5287693	total: 11.2s	remaining: 1.67s
# 435:	learn: 8.5024323	total: 11.2s	remaining: 1.64s
# 436:	learn: 8.4921930	total: 11.2s	remaining: 1.61s
# 437:	learn: 8.4856542	total: 11.3s	remaining: 1.59s
# 438:	learn: 8.4706258	total: 11.3s	remaining: 1.56s
# 439:	learn: 8.4533121	total: 11.3s	remaining: 1.53s
# 440:	learn: 8.4261245	total: 11.3s	remaining: 1.51s
# 441:	learn: 8.4095242	total: 11.4s	remaining: 1.49s
# 442:	learn: 8.4077611	total: 11.4s	remaining: 1.46s
# 443:	learn: 8.3969898	total: 11.4s	remaining: 1.43s
# 444:	learn: 8.3870376	total: 11.5s	remaining: 1.42s
# 445:	learn: 8.3615544	total: 11.5s	remaining: 1.39s
# 446:	learn: 8.3500283	total: 11.5s	remaining: 1.36s
# 447:	learn: 8.3276070	total: 11.5s	remaining: 1.33s
# 448:	learn: 8.3108187	total: 11.5s	remaining: 1.3s
# 449:	learn: 8.2916133	total: 11.6s	remaining: 1.28s
# 450:	learn: 8.2854860	total: 11.6s	remaining: 1.25s
# 451:	learn: 8.2752025	total: 11.6s	remaining: 1.23s
# 452:	learn: 8.2655195	total: 11.7s	remaining: 1.21s
# 453:	learn: 8.2319817	total: 11.7s	remaining: 1.18s
# 454:	learn: 8.2084591	total: 11.7s	remaining: 1.15s
# 455:	learn: 8.1955095	total: 11.7s	remaining: 1.13s
# 456:	learn: 8.1953124	total: 11.7s	remaining: 1.1s
# 457:	learn: 8.1868819	total: 11.8s	remaining: 1.08s
# 458:	learn: 8.1665767	total: 11.8s	remaining: 1.05s
# 459:	learn: 8.1463143	total: 11.8s	remaining: 1.02s
# 460:	learn: 8.1295196	total: 11.8s	remaining: 1s
# 461:	learn: 8.1031311	total: 11.9s	remaining: 975ms
# 462:	learn: 8.0934282	total: 11.9s	remaining: 947ms
# 463:	learn: 8.0874689	total: 11.9s	remaining: 920ms
# 464:	learn: 8.0791756	total: 11.9s	remaining: 899ms
# 465:	learn: 8.0741695	total: 11.9s	remaining: 872ms
# 466:	learn: 8.0546343	total: 12s	remaining: 845ms
# 467:	learn: 8.0405072	total: 12s	remaining: 817ms
# 468:	learn: 8.0063400	total: 12s	remaining: 796ms
# 469:	learn: 7.9858654	total: 12s	remaining: 769ms
# 470:	learn: 7.9742422	total: 12.1s	remaining: 742ms
# 471:	learn: 7.9537791	total: 12.1s	remaining: 715ms
# 472:	learn: 7.9509514	total: 12.1s	remaining: 693ms
# 473:	learn: 7.9343682	total: 12.1s	remaining: 666ms
# 474:	learn: 7.9211535	total: 12.2s	remaining: 640ms
# 475:	learn: 7.8923677	total: 12.2s	remaining: 613ms
# 476:	learn: 7.8858211	total: 12.2s	remaining: 590ms
# 477:	learn: 7.8768806	total: 12.2s	remaining: 564ms
# 478:	learn: 7.8504097	total: 12.2s	remaining: 537ms
# 479:	learn: 7.8249441	total: 12.3s	remaining: 511ms
# 480:	learn: 7.8029854	total: 12.3s	remaining: 487ms
# 481:	learn: 7.7863623	total: 12.3s	remaining: 461ms
# 482:	learn: 7.7635539	total: 12.3s	remaining: 435ms
# 483:	learn: 7.7542855	total: 12.3s	remaining: 408ms
# 484:	learn: 7.7485741	total: 12.4s	remaining: 385ms
# 485:	learn: 7.7228388	total: 12.4s	remaining: 358ms
# 486:	learn: 7.7154600	total: 12.4s	remaining: 332ms
# 487:	learn: 7.7116592	total: 12.4s	remaining: 306ms
# 488:	learn: 7.7021066	total: 12.5s	remaining: 282ms
# 489:	learn: 7.6792820	total: 12.5s	remaining: 256ms
# 490:	learn: 7.6735636	total: 12.5s	remaining: 230ms
# 491:	learn: 7.6644687	total: 12.5s	remaining: 204ms
# 492:	learn: 7.6446971	total: 12.6s	remaining: 179ms
# 493:	learn: 7.6326031	total: 12.6s	remaining: 154ms
# 494:	learn: 7.6233798	total: 12.6s	remaining: 128ms
# 495:	learn: 7.6062772	total: 12.6s	remaining: 102ms
# 496:	learn: 7.5896626	total: 12.7s	remaining: 76.9ms
# 497:	learn: 7.5833482	total: 12.7s	remaining: 51.2ms
# 498:	learn: 7.5680762	total: 12.7s	remaining: 25.5ms
# 499:	learn: 7.5515598	total: 12.7s	remaining: 0us

# %%
model_results_df = pd.DataFrame({'model': ['LinearRegression', 'RandomForestRegressor', 'CatBoostRegressor'],
              'best_rmse': [best_lr_rmse, best_rf_rmse, best_cb_rmse],
              'train_time': [best_lr_time, best_rf_time, best_cb_time]})

# %%
model_results_df
# Out:
#                    model  best_rmse  train_time
# 0       LinearRegression  48.616597        0.07
# 1  RandomForestRegressor  53.613306      212.45
# 2      CatBoostRegressor  45.947676      780.89

# %%
# best CatBoostRegressor model params
best_cb_model.get_all_params()
# Out:
# {'nan_mode': 'Min',
#  'eval_metric': 'RMSE',
#  'iterations': 500,
#  'sampling_frequency': 'PerTree',
#  'fold_permutation_block': 0,
#  'leaf_estimation_method': 'Newton',
#  'boosting_type': 'Plain',
#  'feature_border_type': 'GreedyLogSum',
#  'bayesian_matrix_reg': 0.1000000015,
#  'l2_leaf_reg': 3,
#  'random_strength': 1,
#  'rsm': 1,
#  'boost_from_average': True,
#  'model_size_reg': 0.5,
#  'approx_on_full_history': False,
#  'subsample': 0.8000000119,
#  'use_best_model': False,
#  'random_seed': 42,
#  'depth': 8,
#  'has_time': False,
#  'fold_len_multiplier': 2,
#  'border_count': 254,
#  'classes_count': 0,
#  'sparse_features_conflict_fraction': 0,
#  'leaf_estimation_backtracking': 'AnyImprovement',
#  'best_model_min_trees': 1,
#  'model_shrink_rate': 0,
#  'loss_function': 'RMSE',
#  'learning_rate': 0.1000000015,
#  'score_function': 'Cosine',
#  'task_type': 'CPU',
#  'leaf_estimation_iterations': 1,
#  'bootstrap_type': 'MVS',
#  'permutation_count': 4}

# %% [markdown]
# 1) 3 models were trained and tested in using grid search based on number of iterations and depth_size using 5 fold
# time-series cross validation; the end result is that CatBoostRegressor had the lowest RMSE of all 3 models, although
# the training time it took is also among the highest at 780 seconds.

# %% [markdown]
# ## Testing

# %%
def test_prediction(model, test_X, test_y):
    """
    Predict RMSE on the test set
    """
    start_time = time.time()
    preds = model.predict(test_X)
    return preds, np.round(time.time(), 2) - start_time, rmse(test_y, preds)

# %%
preds, pred_time, best_rmse = test_prediction(best_cb_model, test_X.values, test_y)
print(f'The RMSE on the test set is {np.round(best_rmse, 2)}, and time to predict {np.round(pred_time, 4)} seconds')
# Out:
# The RMSE on the test set is 45.95, and time to predict 0.0093 seconds

# %% [markdown]
# #### Feature importance

# %%
pd.DataFrame(best_cb_model.feature_importances_,
index=train_X.columns, columns=['score']).sort_values('score', ascending=False)
# Out:
#                     score
# hour            35.268336
# lag_1           10.005105
# month            7.830481
# lag_7            5.958891
# lag_2            5.666180
# dayofweek        5.029303
# lag_3            4.671872
# lag_5            4.358166
# rolling_std      4.062988
# lag_6            4.046287
# lag_4            3.865442
# day              3.605451
# rolling_mean     3.202499
# rolling_median   2.428998

# %% [markdown]
# 1) The RMSE on the test set, using the model with the lowest RMSE, is 45 orders.
#
# 2) The top 3 important features are: hour, lag_1, month.

# %%
len(preds)
# Out:
# 882

# %%
test_set = test_X.merge(df_hourly['num_orders'], left_index=True, right_index=True)['num_orders']
pd.DataFrame(test_set, columns=['num_orders']
#test_set['preds'] = preds[0]
#test_set
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Summary**
#
# 1) The mean `num_orders` shows an upward trend in the last 5 months between 2018-03-01 and 2018-08-31.
#
# 2) The data was prepared by creating several date and time-series related features, such as, `month`, `day`, `dayofweek`, `hour`,
# `lag_*`, `rolling_mean`, `rolling_median`, and `rolling_std`.
#
# 3) The decomposition of time-series components shows a daily seasonality, which peaks at 12 AM, and drops to its lowest at 6AM, and
# during the day peaks at around 5PM.
#
# 4) The residuals reveals that the mean is not 0, which could bias the forecast.
#
# 5) CatBoostRegressor emerged as the best model with the lowest RMSE. However, it also took the longest to train the model.
